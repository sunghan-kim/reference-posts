# %% [markdown]
# # Naver 검색 API 사용하기

# %% [markdown]
# [Naver 검색 API 사용하기](https://pinkwink.kr/1139)

# %% [markdown]
# [NAVER Developers](https://developers.naver.com/main/)

# %% [markdown]
# <br>

# %%
client_id = 'qzceB4vKYciM5gSicPeY'
client_secret = 'K68V2HYjnt'

# %%
import urllib

def make_naver_search_api_url(node, search_text, start_num, disp_num) :
    base_url = "https://openapi.naver.com/v1/search/" + node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    
    return base_url + param_query + param_start + param_disp

# %%
import urllib.request

def get_request_url(API_url, client_id, client_secret) :
    request = urllib.request.Request(API_url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    
    response = urllib.request.urlopen(request)
    if response.getcode() == 200 :
        return response.read().decode('utf-8')
    else :
        return None
        print("--- error ---")

# %%
api_url = make_naver_search_api_url('news','경남도지사',1,10)
print(get_request_url(api_url, client_id, client_secret))
# Out:
# {
# "lastBuildDate": "Fri, 16 Aug 2019 12:52:21 +0900",
# "total": 114124,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "한돈협 <b>경남도</b>협의회, 한돈으로 소외계층에 농가 온정 전달",
# "originallink": "http://www.chuksannews.co.kr/news/article.html?no=200653",
# "link": "http://www.chuksannews.co.kr/news/article.html?no=200653",
# "description": "이어, 김경수 <b>경남도지사</b>는 “우리 지역에서 생산된 맛있고 품질 좋은 축산물이 도민에게 우선 공급되고 수도권까지 판로가 확대될 수 있도록 함께 힘을 모으겠다”고 화답했다.",
# "pubDate": "Fri, 16 Aug 2019 11:13:00 +0900"
#
# },
# {
# "title": "김해신공항 재검증 판정위 8월 중 구성되나",
# "originallink": "http://www.gimhaenews.co.kr/news/articleView.html?idxno=29382",
# "link": "http://www.gimhaenews.co.kr/news/articleView.html?idxno=29382",
# "description": "판정위 구성은 오거돈 부산시장과 김경수 <b>경남도지사</b>가 지난 13일 이낙연 국무총리를 만난 뒤 급물살을 탔다. 이들은 이날 서울정부청사에서 만나 김해신공항 건설안 재검증 판정위를 어떻게 구성할지를 논의한 것으로... ",
# "pubDate": "Fri, 16 Aug 2019 10:32:00 +0900"
#
# },
# {
# "title": "<b>경남도</b>,日 수출규제, 민·관·정 협의회 개최",
# "originallink": "http://www.asiatoday.co.kr/view.php?key=20190816010008747",
# "link": "http://www.asiatoday.co.kr/view.php?key=20190816010008747",
# "description": "김경수 <b>경남도지사</b> 주재로 일본 수출규제 대응책과 추진방향 등을 논의하기 위한 ‘대외경제 민·관... 중소기업융합<b>경남</b>연합회 등 6개 민간단체와 기관, <b>경남도</b>의회 의원 및 한국전기연구원, 재료연구소 등 7개 <b>도</b>... ",
# "pubDate": "Fri, 16 Aug 2019 10:02:00 +0900"
#
# },
# {
# "title": "[포토] 김경수 <b>경남도지사</b>,74주년 광복절 경축사",
# "originallink": "http://www.asiatoday.co.kr/view.php?key=20190816010008742",
# "link": "http://www.asiatoday.co.kr/view.php?key=20190816010008742",
# "description": "김경수 <b>경남</b><b>지사</b>는 15일 도청 신관에서 거행된 ‘제74주년 광복절 경축식’에서 “우리 미래 세대들이 역사에서 긍지를 느끼고 나라를 사랑하게 하는 힘은 보훈에 있다”면서 “우리 아이들이 커서 어른이 될 때쯤이면... ",
# "pubDate": "Fri, 16 Aug 2019 10:02:00 +0900"
#
# },
# {
# "title": "“일본 경제보복, 산업생태계 전환 계기로 삼자”",
# "originallink": "http://www.knnews.co.kr/news/articleView.php?idxno=1299100",
# "link": "http://www.knnews.co.kr/news/articleView.php?idxno=1299100",
# "description": "지난 14일 도청에서 열린 일본 경제보복 대응 ‘대외경제 민·관·정협의회’ 전체회의./<b>경남도</b>/ 김경수 <b>경남도지사</b>는 14일 일본의 경제보복 대응과 관련해 “대기업과 중소기업의 상생을 통한 위기 극복으로 대한민국 경제... ",
# "pubDate": "Fri, 16 Aug 2019 10:00:00 +0900"
#
# },
# {
# "title": "김경수 <b>경남도지사</b>, “위기를 기회로&quot;..日수출규제, 민관정 협의체 구성",
# "originallink": "http://kpenews.com/View.aspx?No=86099",
# "link": "http://kpenews.com/View.aspx?No=86099",
# "description": "회의를 주재한 김경수 <b>도지사</b>는 “이번 기회에 대기업과 중소기업의 상생을 통한 위기 극복으로 대한민국... 등 6개 민간단체와 기관, <b>경남도</b>의회 의원 및 한국전기연구원, 재료연구소 등 7개 <b>도</b> 출자출연기관이 참석했다.",
# "pubDate": "Fri, 16 Aug 2019 09:55:00 +0900"
#
# },
# {
# "title": "김경수 <b>지사</b> &quot;평화·정의·번영의 통일된 새로운 사회 기대&quot;",
# "originallink": "http://www.kndaily.co.kr/news/articleView.html?idxno=107084",
# "link": "http://www.kndaily.co.kr/news/articleView.html?idxno=107084",
# "description": "김경수 <b>경남도지사</b>가 &quot;평화-정의-번영의 통일된 새로운 사회를 기대한다&quot;고 말했다. 김경수 <b>지사</b>는 15일 오전 도청 신관 대강당에서 거행된 제74주년 광복절 경축식에서 &quot;우리 미래 세대들이 역사에서 긍지를 느끼고 나라를... ",
# "pubDate": "Fri, 16 Aug 2019 09:53:00 +0900"
#
# },
# {
# "title": "[경마브리핑]어차피 올해 여왕은 실버울프?",
# "originallink": "https://www.sedaily.com/NewsView/1VMZQ4ZOCT",
# "link": "http://sports.news.naver.com/general/news/read.nhn?oid=011&aid=0003603927",
# "description": "이번에 1위를 차지한다면 오는 11월 열리는 3차전 <b>경남도지사</b>배에서 퀸즈투어 싹쓸이 우승 재연을 노릴 수 있게 된다. 변함없이 단짝인 유승완 기수가 호흡을 맞춘다. 담양환호(부경·미국·암·5세·레이팅90)와... ",
# "pubDate": "Fri, 16 Aug 2019 09:15:00 +0900"
#
# },
# {
# "title": "<b>도지사</b>배 전국요트대회 30일 통영서 개막",
# "originallink": "http://www.idomin.com/news/articleView.html?idxno=705521",
# "link": "http://www.idomin.com/news/articleView.html?idxno=705521",
# "description": "<b>경남도지사</b>배 전국요트대회는 지난 2013년부터 아름다운 <b>경남</b> 해안선을 잇는 통영시, 고성군, 남해군 등에서 개최됐다. 백승섭 <b>도</b> 해양수산국장은 &quot;<b>경남</b> 연안 시·군의 해양레저 분야 교류와 <b>경남</b>의 해양레저관광... ",
# "pubDate": "Fri, 16 Aug 2019 06:04:00 +0900"
#
# },
# {
# "title": "[오늘의 주요일정] <b>경남</b>(16일, 금)",
# "originallink": "http://news1.kr/articles/?3696614",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=421&aid=0004147346",
# "description": "◇<b>경남도</b> -김경수 <b>도지사</b> 공식일정 없음 ◇창원시 -허성무 시장 09:00 간부공무원 티타임(집무실) 11:00 기업체 현장 방문(동환산업) 14:30 주요 현안부서 업무계획(집무실)",
# "pubDate": "Fri, 16 Aug 2019 05:00:00 +0900"
#
# }
# ]
# }

# %%
api_url = make_naver_search_api_url('blog','경남도지사',1,10)
print(get_request_url(api_url, client_id, client_secret))
# Out:
# {
# "lastBuildDate": "Fri, 16 Aug 2019 12:52:48 +0900",
# "total": 86783,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "차기 <b>경남도지사</b> 적합도",
# "link": "https://gnhong.com/entry/%EC%B0%A8%EA%B8%B0-%EA%B2%BD%EB%82%A8%EB%8F%84%EC%A7%80%EC%82%AC-%EC%A0%81%ED%95%A9%EB%8F%84?category=294659",
# "description": "7, 윤한홍 전 경남도 행정부지사 1.5%순으로 조사되었다. 그러나, 차기 <b>경남도지사</b>와 관련해 ‘적합한 인물이 없다’(25.1%)는 의견과 ‘잘 모르겠다’(23.1%)는 의견 등 부동층이 48.1%로 매유 높게... ",
# "bloggername": "강릉사랑 홍준일",
# "bloggerlink": "https://gnhong.com/",
# "postdate": "20171107"
#
# },
# {
# "title": "김경수 <b>경남도지사</b> 후보 전진대회",
# "link": "https:\/\/blog.naver.com\/choovision?Redirect=Log&logNo=221274944232",
# "description": "안녕하세요 홍비서입니다 5월 9일 <b>경남</b> 필승전진대회 가 있었습니다! 그 며칠 전 홍비서는... <b>도지사</b>후보는 =.....=..... !?!?!?!????!??!?! 김경수 후보님이요!?!?!?!? 진짜...진짜요...? 진짜..진짜...? (제가 정말 거짓말... ",
# "bloggername": "더불어민주당 국회의원 추미애",
# "bloggerlink": "https://blog.naver.com/choovision",
# "postdate": "20180513"
#
# },
# {
# "title": "김경수 <b>경남도지사</b> 후보 공천 과연 노무현정신에 ??",
# "link": "https://sunbee.tistory.com/449",
# "description": "설사 <b>경남도지사</b>를 야당에 넘겨주는 한이 있더라도 국민에 대한 신의는 지키는 것이 옳다고 본다. 5천년 역사를 보면 도지사 임기 4년은 그야말로 잠시잠깐의 시간에 불과하다. 그 잠시잠깐의 4년 동안 경남의... ",
# "bloggername": "선비(sunbee)HOME",
# "bloggerlink": "http://sunbee.tistory.com/",
# "postdate": "20180321"
#
# },
# {
# "title": "특검' 김경수 지사 구속영장 청구…김경수 <b>경남도지사</b> &quot;강한 유감&quot;",
# "link": "https:\/\/blog.naver.com\/srchcu?Redirect=Log&logNo=221339686692",
# "description": "'드루킹 허익범 특검' 김경수 지사 구속영장 청구…김경수 <b>경남도지사</b> &quot;강한 유감&quot; 김경수 지사는... 2018.8.10/뉴스1 © News1 유승관 기자 (요약글)허익범 특별검사팀이 15일 밤 김경수 경남지사에 대해... ",
# "bloggername": "준영사랑",
# "bloggerlink": "https://blog.naver.com/srchcu",
# "postdate": "20180816"
#
# },
# {
# "title": "경남 출신 4선 김영선 전 의원, <b>경남도지사</b> 출마 행보 본격화",
# "link": "https:\/\/blog.naver.com\/youngsun425?Redirect=Log&logNo=221085378828",
# "description": "경남 출신 4선 김영선 전 의원, <b>경남도지사</b> 출마 행보 본격화 내년 6.13 지방선거를 앞두고 자유한국당... 그러면서 “홍준표 전 지사에 이어 연속성을 가지고 경남 미래 50년 사업과 대표산업의 경쟁력 제고를... ",
# "bloggername": "김영선 블러그",
# "bloggerlink": "https://blog.naver.com/youngsun425",
# "postdate": "20170830"
#
# },
# {
# "title": "[세바십37] 6.13 지방선거 결과, 김경수 <b>경남도지사</b> 당선",
# "link": "https:\/\/blog.naver.com\/sdpolaris?Redirect=Log&logNo=221299013241",
# "description": "후보 <b>경남도지사</b> 당선 깨달은 것 잠시 떠나있던 몇년을 제외하고 순수 경상도에서만 25년을 살았다. 그런 내게 이번 지방선거결과는 거의 기적과도 같다. 솔직히 무소속은 몰라도 민주당 출신 도지사가 나오는... ",
# "bloggername": "챨리와 초콜릿 문화",
# "bloggerlink": "https://blog.naver.com/sdpolaris",
# "postdate": "20180614"
#
# },
# {
# "title": "<b>경남도지사</b> 후보 김유근 세번째 공약",
# "link": "https:\/\/blog.naver.com\/newadsky?Redirect=Log&logNo=221272335887",
# "description": "설립했지만, 어린이만을 위한 병상 수가 적다 보니 여러 지역에서 우리 병원을 찾는다”고 말했다. #김유근 #<b>경남도지사</b> #바른미래당 #후보 #6.13지방선거 #김경수 #김태호 #공약 #어린이병원 #경남 #경상남도",
# "bloggername": "바른미래당 경남도지사예비후보 김유근",
# "bloggerlink": "https://blog.naver.com/newadsky",
# "postdate": "20180510"
#
# },
# {
# "title": "'댓글조작 공모' 김경수 <b>경남도지사</b> 결심공판",
# "link": "https:\/\/blog.naver.com\/naverlaw?Redirect=Log&logNo=221428888501",
# "description": "/사진=뉴스1 '드루킹' 김모씨와 댓글조작을 공모한 혐의를 받고 있는 김경수 <b>경남도지사</b>의 1심 공판이 마무리 단계에 접어듭니다. 서울중앙지법 형사합의32부(부장판사 성창호)는 28일 오전 10시 김 지사에 대한... ",
# "bloggername": "네이버 법률",
# "bloggerlink": "https://blog.naver.com/naverlaw",
# "postdate": "20181228"
#
# },
# {
# "title": "연담(蓮潭)의 <b>경남도지사</b> 김경수 사주 분석",
# "link": "https:\/\/blog.naver.com\/counselor518?Redirect=Log&logNo=221455075527",
# "description": "戊戌年(2018년) : 戊甲沖으로 甲己(土) 合絆을 깨뜨렸기 때문에 제37대 <b>경남도지사</b> 당선. 3. 己巳年(1989년) : 甲己(土) 合絆으로 구속. 4. 己亥年(2019년) : 甲己(土) 合絆으로 도지사 권한 중지 및 구속. ▶ 己土(나)가... ",
# "bloggername": "연담(蓮潭) 명리학 연구원",
# "bloggerlink": "https://blog.naver.com/counselor518",
# "postdate": "20190130"
#
# },
# {
# "title": "법원,댓글 조작 혐의 김경수 <b>경남도지사</b> 징역 2년 선고 법정구속",
# "link": "https:\/\/blog.naver.com\/parkhs43?Redirect=Log&logNo=221454785819",
# "description": "'드루킹' 일당과 공모해 댓글 조작을 벌인 혐의로 불구속 기소된 김경수 <b>경남</b><b>지사</b>가 1심에서 실형을 선고받고 법정 구속됐다. 선출직 공무원이 공직선거법 위반 혐의로 징역형이나 100만원 이상의 벌금형이... ",
# "bloggername": "박현수기자의 블로그",
# "bloggerlink": "https://blog.naver.com/parkhs43",
# "postdate": "20190130"
#
# }
# ]
# }
